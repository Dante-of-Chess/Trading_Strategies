# %%
import pandas as pd
import numpy as np
import yfinance as yf
import math
import pandas as pd
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# # tickers=pd.read_excel('Stock List.xlsx')
# tickers=tickers[:2000]
# tickers=tickers[tickers['Country']!='India']
# tickers.to_excel('SPX500Check.xlsx')

# %%
# print(tickers.head())
tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
All_Tickers=tickers.Symbol.to_list()

All_Tickers.append('QQQ')
All_Tickers.append('^GSPC')
All_Tickers.remove('FSLR')

# All_Tickers.extend(['TSM',
# 'NVO',
# 'MC.PA',
# 'TCEHY',
# 'NESN.SW',
# 'ASML',
# 'OR.PA',
# 'TM',
# 'IHC.AE',
# 'ROG.SW',
# 'RMS.PA',
# 'SHEL',
# 'RELIANCE.NS',
# 'AZN',
# 'NVS',
# 'BABA',
# 'PDD',
# 'SAP',
# 'BHP',
# 'HDB',
# 'TCS.NS',
# 'TTE',
# 'HSBC',
# 'SIE.DE',
# 'RY',
# 'CDI.PA',
# 'IDEXY',
# 'PRX.AS',
# 'BUD',
# 'CBA.AX',
# 'SNY',
# 'AIR.PA',
# 'UL',
# 'RIO',
# 'DTE.DE',
# 'SONY',
# 'TD',
# 'SU.PA',
# 'TAQA.AE',
# 'ALV.DE',
# 'PBR',
# 'MUFG',
# 'NPPXF',
# 'AI.PA',
# 'BP',
# '300750.SZ',
# 'SHOP',
# 'UBS',
# '1299.HK',
# '3968.HK',
# 'EQNR',
# 'CSL.AX',
# 'EL.PA',
# 'IBN',
# '0883.HK',
# 'ABBN.SW',
# 'CNI',
# 'DEO',
# 'IBE.MC',
# 'CFR.SW',
# '002594.SZ',
# 'P911.DE',
# 'ATCO-B.ST',
# 'BNP.PA',
# 'MELI',
# '000660.KS',
# '373220.KS',
# 'ARM',
# 'INFY',
# '000858.SZ',
# 'ENB',
# 'ZURN.SW',
# 'GSK',
# 'ENEL.MI',
# 'RELX',
# 'MBG.DE',
# 'CS.PA',
# 'CP',
# 'GLCNF',
# 'KKR',
# 'WMMVF',
# 'BMW.DE',
# 'SAF.PA',
# 'BHARTIARTL.NS',
# 'WDAY',
# 'DG.PA',
# 'BMO',
# 'CNQ',
# 'INVE-B.ST',
# 'STLA',
# 'ROSN.ME',
# 'MRK.DE',
# 'ITC.NS',
# 'VALE',
# 'SBIN.NS',
# 'ITUB',
# 'SAN',
# 'TRI',
# 'SCCO',
# 'DSY.PA',
# '3690.HK',
# '0728.HK',
# 'BTI',
# 'SNOW',
# 'D05.SI',
# 'NAB.AX',
# '9633.HK',
# 'SBER.ME',
# 'SHL.DE',
# 'SMFG',
# 'ADNOCGAS.AE',
# 'VOW3.DE',
# 'LSEG.L',
# 'LICI.NS',
# 'BN',
# 'TEAM',
# 'CRWD',
# 'RACE',
# 'FMG.AX',
# 'HDFC.NS',
# 'NTES',
# 'BNS',
# 'DHL.DE',
# 'BRK-B'])
# Removed=['DVD', 'ASCMA', 'CON.L', 'CICN', 'NSH.L', 'UNDT', 'ORNC', 'PATSPINLTD.NS', 'SYKE', 'ALXN', 'INL.L', 'OMCM', 'HCCI', 'VAR', 'CVLA.BE', 'ESSDEE.NS', 'ESG.L', 'BVS.L', 'PRP.L', 'FNGN', 'MWG.L', 'HMLH.L', 'ZNH', 'NPTN', 'IPHI', 'VCMG', 'AGN', 'MIC', 'CCXI', 'SALONACOT.NS', 'SZ1.F', 'CSOD', 'RAD', 'L1OA.F', 'AFRS', 'BSRC', 'LTM', 'HBSTOCK.NS', 'SXCP', 'SYTE', 'ADLABS.NS', 'KU2.F', 'IMI', 'RWE3.BE', 'AKR.L', 'IMO.L', 'COM.MU', 'SCIO', 'TIRTZ', 'PRHL', 'BCOR', 'EMIS', 'AXE', 'BINDALAGRO.NS', 'E2F.F', 'JFB.F', 'MLC.L', 'ECOM', 'NCCL.L', 'LEAF.L', 'HSC', 'ABC', 'VIPUL.NS', 'WIN.F', 'SBTB', 'ARO.L', 'HDS', 'SPR.BE', 'CHFC', 'JEC', 'MTPH.L', 'GSJ.F', 'AM3D.MU', 'TTPH', 'TLI.F', 'HYDG.L', 'VVUS', 'CCMP', 'AAA.L', 'BREW', 'AMBR', 'VT9.BE', 'CBB', 'MMRF', 'ELRN', 'IPAPPM.NS', 'NITESHEST.NS', 'PSYS', 'KBC.MU', 'FLKM', 'GRUH.NS', 'IIVI', 'MERL.L', 'STOB.L', 'ASNA', 'QADA', 'ERM.L', 'SFLY', 'QSC.MU', 'MCPI', 'PIRPHYTO.NS', 'CFMS', 'STL', 'FII', 'CSX1.BE', 'DMGT.L', 'YBIN', 'TCM.L', 'LMNX', 'SPNI', 'TOT.L', 'PV3.F', 'HSV.L', 'CTRP', 'BPI', 'NIHD', 'SHRC', 'ITG', 'CY', 'VG', 'NVIC', 'VLDI', 'TURV', 'FMBI', 'VT9.F', 'WPG', 'BRD.L', 'AVRN', 'AGK.L', 'CSFL', 'INFI', 'MINDTREE.NS', 'MPSP', 'DATA', 'NAV', 'KGP.L', 'GPX', 'SIGNETIND.NS', 'APTS', 'RLGY', 'DRE', 'PFSD', 'OMED', 'SKBI', 'ALOKTEXT.NS', 'I', 'HER.L', 'LUS.MU', 'BITA', 'GSH', 'HMLP', 'SGM.L', 'NEWAY.AS', 'MANGTIMBER.NS', 'ADD.BE', 'IS8.MU', 'ECM.L', 'DGJI', 'YOLO.L', 'WAGE', 'TYPE', 'MOBL', 'GAL.NS', 'IIJI', 'S7E.MU', 'BLL', 'SHLO', 'PTEO', 'BHBK', 'MBFI', 'DSPG', 'AM3D.F', 'SREINFRA.NS', 'MAN3.F', 'SZZ.F', 'GBLL', 'WMGI', 'NASA.L', 'VRTT', 'MFST', 'PFG.L', 'BARZ', 'OIBR-C', 'SNHY', 'ARROWTEX.NS', 'CLD', 'GEMINI.NS', 'SRIPIPES.NS', 'SLI.L', 'MORT.L', 'GLOBOFFS.NS', 'GEC.MU', 'KCAP', 'STR.L', 'ITNM', 'SGR.L', '93M.BE', 'MNZS.L', 'OBT.L', 'CDR', 'NUVA', 'LFC', 'STAY', 'ORIT', 'PVR.NS', 'GCAP', 'CELG', 'PSID', 'RPC.L', 'ZNCM', 'AFRB.L', 'DRI.F', 'HBMK', 'DPLO', 'VIH.BE', 'IAIC', 'AXIO', 'RST', 'CORPBANK.NS', 'BWO.L', 'MCE.F', 'HEMA', 'JE', 'ANH', 'SPPI', 'KTIL.NS', 'NEMD', 'CCOM', 'GUJNRECOKE.NS', 'MTMY.L', 'ISH2.BE', 'TCO', 'SGC.L', 'MDMG.L', 'ADT.L', 'MNI', 'IROG', 'GLYE', 'ORIENTREF.NS', 'CHGT', 'CLGX','EFII', 'YEWB', 'CBEV', 'RBCC', 'AMARAJABAT.NS', 'EUCA.F', 'RCII', 'VUOC', 'SINA', 'GTS', 'WWE', 'DF', 'OROE', 'QTMM', 'CPSL', 'WYG.L', 'XLNX', 'RP', 'PHII', 'BPFH', 'MDCO', 'SMP.L', 'LEXG', 'SCHS', 'TMK', 'ISH2.F', 'GPOR.L', 'STCK.L', 'ITKG', 'THEBYKE.NS', 'COS.L', 'FFG', 'MSG', 'JW-A', 'OPBL', 'ISAT.L', 'WMH.L', 'GWI1.BE', 'CLL.L', 'MCIG', 'SREV', 'MKRS', 'EVSI', 'SPDL', 'PEI', 'ANAT', 'GFIN.F', 'IDEA.L', 'TUNG.L', 'BCOM', 'DRSV', 'HZNP', 'N7G.MU', 'CIR', 'LLL', 'SAC.F', 'ATRM', 'KAZ.L', 'LMI.L', 'RM2.L', 'MAHINDCIE.NS', 'ODX.L', 'ABHD', 'HEZ.BE', 'SRNA', 'SINTEX.NS', 'OGES', 'ACCEL.AS', 'FRLF', 'GWB', 'CATM', 'HZD.L', 'OCT.L', 'CVTI', 'PSNP', 'ORCHIDPHAR.NS', 'EROS', 'GRSU', 'EDL.L', 'NTP', 'WRE', 'RPAI', 'GMLP', 'BERK', 'ANR.L', 'AEGN', 'SUJANAUNI.NS', 'TWTR', 'JRJC', 'EMQ.MU', 'S3F.F', 'GTQ1.F', 'SOUL', 'AT', 'SITASHREE.NS', 'TOO', 'LXFT', 'DUPD.L', 'AUCT.L', 'EBML', 'VRTA', 'HP3.F', 'MAN.BE', 'AKS', 'PSL.NS', 'LM', 'BRKK', 'GAMMNINFRA.NS', 'DTG.L', 'USBL', 'INWK', 'WEIN', 'SIGM', '93M.F', 'MGI', 'WIN', 'GTXO', 'CELO', 'SSW', 'WL6.MU', 'NNS.MU', 'CYOU', 'SANGHVIFOR.NS', 'PZN', 'FTR', 'SCIN.L', 'RHT', 'MCE.BE', 'FPRX', 'CAJ', 'LTEC.BE', 'RUTH', 'GLBD', 'ERMK.F', 'LIO1.BE', 'TXH.L', 'DSFN', 'ANDHRABANK.NS', 'SGMS', 'CREE', 'UIS.F', 'EUSP.L', 'AMAR', 'RKET.MU', 'JOBS', 'ICT.AS', 'K1R.F', 'VALUEIND.NS', 'CROL', 'MWOG', 'TBK', 'EXNT', 'NCS', 'GTMM', 'IDTI', 'BBX', 'GRPX', 'COM.F', 'GNK.L', 'SZZ.BE', 'BDGE', 'EPZM', 'ONDK', 'OPHT', 'AR4.F', 'WUBA', 'GPNE', 'IME.L', 'DDE', 'UANC.L', 'CAI', 'PTPF', 'AAWW', 'KTYB', 'CNBKA', 'ELLI', 'PRADIP.NS', 'USHERAGRO.NS', 'GLTC', 'NP', 'WL6.F', 'VIJAYABANK.NS', 'SXX.L', 'TATASPONGE.NS', 'SDL.L', 'CTDT', 'CZZ', 'FELP', 'SPR.F', '0QAX.L', 'CCAN', 'ERMK.BE', 'CPFH', 'LDHL', 'DGDM', 'MLES', 'PTLA', 'AAST', 'JLT.L', 'CPL', 'WIN.MU', 'DNKN', 'ANTM', 'RLH', 'VCSY', 'VWS.BE', 'MED.L', 'BON.L', 'C21.L', 'GWR', 'GNBT', 'SVST.L', 'BIL.BE', 'LORL', 'LHCG', 'TQLA', 'AHC', 'CBBT', 'UPNT', 'NUAN', 'DIRV', 'PGCG', 'CEL', 'DCT', 'EMIS.L', 'PDLI', 'AFHP.L', 'TEF.L', 'ISAT', 'DRNA', 'BAGR.L', 'UBSH', 'AIMC', 'LWRF.L', 'UTTAMSTL.NS', 'AVGG', 'NATNLSTEEL.NS', 'NAVG', 'STT.BE', 'SCHN', 'FLX.L', 'LID.L', 'SQSBFSI.NS', 'SHB.L', 'PICO', 'UBA', 'TECD', 'GBT', 'ADLS', 'CSLT', 'TMKS.L', 'JAX', 'PGEC', 'MAGAA', 'BAFNAPHARM.NS', 'TPRE', 'AVV.L', 'ISCA', 'RENN', 'CTP.L', 'MANDHANA.NS', 'K1R.BE', 'EDL.NS', 'BILPOWER.NS', 'VAC.BE', 'ZMDC', 'CIT', 'LCI', 'BSHF', 'HDG.AS', 'CURATECH.NS', 'ECT.AS', 'NBVENTURES.NS', 'BCYP', 'WTR', 'NK', 'TILS.L', 'FCBI', 'RTIX', 'ZEN', 'KNL', 'ATU', 'ALM.L', 'UTW.L', 'IBVENTURES.NS', 'YRCW', 'WRI', 'TSS', 'RNWK', 'BLCK', 'TGP', 'VEC', 'OIIM', 'VTC.L', 'HINDSYNTEX.NS', 'NEX.L', 'SGFL.NS', 'FSB', 'RMG.L', 'LCAR', 'APF.L', 'MDCA', 'RMM.L', 'CAP.F', 'FFX.L', 'VENN.L', 'FJET.L', '8KMILES.NS', 'BNT1.F', 'MT4.MU', 'AGFS', 'OMBP', 'UDG.L', 'CAY.L', 'N2F.F', 'MDDD', 'ATMA.L', 'VIAB', 'TAX', 'SPKE', 'FLIR', 'SSOL', 'PRSC', 'WIFI', 'CPS.L', 'SEPOWER.NS', 'TWL.NS', 'NTRI', 'JLH.L', 'EDIG', 'MDSO', 'STND', 'EGDW', 'OPM.L', 'SERV', 'CTR.L', 'CRAY', 'RBS.L', 'COB.L', 'SPNE', 'OBH.BE', 'INTEGRA.NS', 'BSELINFRA.NS', 'WBK', 'DPW.F', 'MA1.F', 'SFOR', 'HMSY', 'TIER', 'CHCR', 'CRCM', 'IIT.L', 'MKLW.L', 'CBAI', 'S4A.F', 'SNE', 'GLPR.L', 'ASSAMCO.NS', 'IVC', 'EPO.L', 'SUMM.L', 'SPIN', 'INFRATEL.NS', 'KABN.BE', 'UTX', 'GNC', 'FIT', 'SRTRANSFIN.NS', 'INM.L', 'ITCC', 'FLY', 'SFEF', 'OTIC', 'MCRO.L', 'NRZ', 'ULS.L', 'SVJ.MU', 'CUB', 'TESS', 'INFO', 'FNSR', 'SC2.BE', 'WCG', 'TALK.L', 'DJAN.L', 'XL', 'FEYE', 'EMPK', 'MCRN', 'ECEIND.NS', 'M3B.BE', 'FIND', 'SYNCOM.NS', 'FUL.L', 'PSMH', 'PSB', 'PARABDRUGS.NS', 'IRLD', 'PENPEBS.NS', 'VRP.L', 'RLBS', 'HLBN.BE', 'STB', 'WETF', 'HPT', 'DODS.L', 'HBPE', 'DLDG', 'MCH.MU', 'PLT', 'RED.L', 'ABGSHIP.NS', 'RGM.L', 'DIAPOWER.NS', 'ATST.L', 'VIH.F', 'LMNK', 'KSU', 'GZT', 'MNK', 'TPAC', 'PHO.L', 'MJMI', 'LGT.L', 'POCHIRAJU.NS', 'NLSN', 'EVTN', 'ASFI', 'ALLM', 'ADS', 'RPXC', 'TCIDEVELOP.NS', 'FAM1.F', 'SLVH', 'MLNX', 'VRTU', 'PWON', 'KEYCORPSER.NS', 'IBKC', 'BRKS', 'SFO.MU', 'LPT', 'DEAC', 'CBPX', 'PTIE', 'ADHUNIK.NS', 'SSI', 'CHSP', 'ALRT', 'ATV', 'BHTG', 'EHIC', 'GALLISPAT.NS', 'ELGX', 'DCIX', 'OLBG', 'FABK', 'ZNGA', 'AMPH.L', 'CTRL', 'AJRD', 'ADVC', 'KU2.BE', 'IOFB', 'BRSS', 'ULTI', 'BNCL', 'BTFL', 'BPY', 'JCDAF', 'TWCF', 'FRGI', 'BGG', 'MNOD.L', 'URA.L', 'A8A.F', 'LLNW', 'GNGT', 'BKCT', 'ALVA.F', 'MINI', 'ACC', 'SC', 'GSJ.BE', 'POC.MU', 'MLER', 'GLOG', 'AMCO', 'HOFD', 'ZEF.BE', 'KWBT', 'CNIC.L', 'USG', 'INXN', 'ISR.MU', 'SCIL', 'MODLF', 'AYR', 'CNCG', 'XON', 'FRC', 'LSE.L', 'ALSK', 'BRY.L', 'RTN1.MU', 'PWVI', 'SAC.MU', 'ALVA.BE', 'QS5.BE', 'HANUNG.NS', 'ADANITRANS.NS', 'CPR.L', 'XLENERGY.NS', 'RIV.L', 'MANT', 'TCG.L', 'IIBK', 'IDAH', 'STOY', 'O1BC.F', 'SIGB.L', 'FCCN.L', 'SBNC.MU', 'CS', 'BABY', 'CNKS.L', 'VLTC', 'GTQ1.MU', 'TUES', 'MRLN', 'GLIF.L', 'MSL', 'SURP', 'GOG.L', 'CG3.MU', 'MFCB', 'DHFL.NS', 'BAYK', 'RAJRAYON.NS', 'SLN.L', 'PROVOGE.NS', 'CCRE', 'AVX', 'NNA', 'CTXS', 'MONSANTO.NS', 'XIX.MU', 'CLDB', 'UNG.L', 'HTA', 'XSPY', 'PGSC', 'OSIR', 'COT', 'RTN', 'KPIT.NS', 'ACHN', 'KARD.AS', 'IRV.L', 'MERCK.NS', 'NACG', 'ATTO', 'DIC.F', 'RSSV', 'CTI.L', 'TCN.L', 'NWHM', 'RDTK', 'WAND.L', 'LABL', 'STAR', 'ECOS', 'STL.L', 'CEBBCO.NS', 'ABBY.L', 'VVIT', 'CBK', 'MCGN.L', 'ZHEH.L', 'HRC', 'BXS', 'DDRI', 'WEIZFOREX.NS', 'CBS', 'ARRS', 'PALRED.NS', 'ZIXI', 'ABJ.BE', 'WAIR', 'PMEA.L', 'NCOM', 'QXT.L', 'COSMOFILMS.NS', 'TRK', 'CMRO', 'CCC', 'CMXX', 'NCI', 'CIR.L', 'KALPATPOWR.NS', 'GRUB', 'BINCK.AS', 'VAC.DE', 'STRI', 'PJC', 'MA1.BE', 'PEBI.L', 'ADL.F', 'ENDP', 'VODG', 'DLG.F', 'PEGI', 'HMTF', 'MN', 'BVBC', 'ANAV', 'PRTX', 'LUS.F', 'SIXD', 'FINANTECH.NS', 'ZBO.L', 'STMP', 'SWM', 'ETO.L', 'ARW.L', 'GNTP', 'ATAX', 'BNT1.BE', 'FLYB.L', 'RLD.L', 'CXP', 'MLHR', 'HOTELEELA.NS', 'ZAR.F', 'SSY.L', 'AXM.L', 'SGUI', 'MIC.NS', 'BCRH', 'MSGO', 'GTSO', 'CERN', 'PCF.L', 'PGRX', 'AUO', 'PDSMFL.NS', 'GLUU', 'ETM', 'EZH.L', 'HSTN.L', 'ITE.L', 'TRQ', 'SCH.L', 'TSC', 'OZM', 'MXMG', 'ZUARIGLOB.NS', 'ATHN', 'PRAH', 'ERA', 'SEZAL.NS', 'TNAV', 'RYA.L', 'CBM', 'IBA', 'WBSI', 'CECE', 'MAGMA.NS', 'SAAX', 'NMUS', 'MRIC', 'FWP', 'DVLY', 'EGOV', 'BBBY', 'OAK', 'PVHO', 'KA.AS', 'BILL.L', 'EIGI', 'NIITTECH.NS', 'THTI', 'UBL.MU', 'SMDM', 'PEYE', 'MTL', 'CSX.MU', 'GROG', 'CBIS', 'ERO1.F', 'CLVS', 'HBM.MU', 'ICON', 'IND.L', 'CLIN.L', 'SIM.L', 'SPA', 'ELY', 'PDUMJEIND.NS', 'PVG', 'JMP', 'GIGL', 'ARL.F', 'PPA.BE', 'PCGE.L', 'SYNDIBANK.NS', 'FIRSTWIN.NS', 'ALR', 'E2F.BE', 'MJTK', 'NOESISIND.NS', 'SZ1.MU', 'MDP', 'BIOS', 'AVN.L', 'ORM.L', 'MXWL', 'PIVN', 'PTD.L', 'VSLR', 'CEV.F', 'EDCI', 'CCOP', 'PS4.BE', 'TALR', 'AUG.L', 'ARDN.L', 'MBTF', 'APC.L', 'AGCNET.NS', 'PGNX', 'RPS.L', 'STI', 'TXSO', 'AWGI', 'EPAY', 'ARNA', 'SFHI', 'HSIL.NS', 'ZYLOG.NS', 'LDB.F', 'N2F.MU', 'OZRK', 'HALN', 'ZENITHBIR.NS', 'SGYP', 'GWI1.F', 'MEL.L', 'MANX.L', 'USAK', 'CCNI', 'ADRO', 'IGOI', 'RTEC', 'RSA.L', 'LAWS', 'MCH.F', 'BCRE.L', 'UIS.MU', 'BEES', 'LSR.L', 'STINDIA.NS', 'SUPREMETEX.NS', 'MONNETISPA.NS', 'STHR.L', 'TTS', 'DRI.BE', 'REPR', 'CWD.L', 'SOG.L', 'AKRX', 'MGGT.L', 'ZFGN', 'TGLP', 'CORE', 'VCRA', 'ABC.L', 'MBT', 'GHDX', 'IVOB', 'SELMCL.NS', 'BGCP', 'SFUN', 'PGD.L', 'PHD.L', 'DIC.BE', 'BT', 'FB', 'FRED', 'LOGG', 'ISR.F', 'JUBILANT.NS', 'CBPO', 'BRW.L', 'TTI.F', 'CAPC.L', 'FRAN', 'EUCA.BE', 'GFS.L', 'TAHO', 'LDB.MU', 'WBAI', 'CHMA', 'CVA', 'BCN.L', 'CTT', 'DPW.MU', 'NTG.L', 'ENGA', 'SALT', 'TBLZ', 'STRZ', 'TULSI.NS', 'IRET', 'PPA.F', 'MXIM', 'ESPH', 'POL.L', 'WGB.L', 'AXMM', 'Y', 'CTWS', 'AFS.L', 'CWRL', 'CEV.BE', 'CTMA.MU', 'MTSC', 'RE', 'CUR.MU', 'AEI.BE', 'IRSB', 'HRS', 'DIC.MU', 'CFX', 'OS3.BE', 'PKWY', 'CRWG', 'DYII', 'MOSB.L', 'HOTELRUGBY.NS', 'UEPS', 'CO', 'CLI', 'AERO', 'FLDM', 'SPAG', 'SPICEMOBI.NS', 'ETH', 'RTNINFRA.NS', 'GBL', 'CSU', 'GS7.MU', 'DENABANK.NS', 'S3F.MU', 'VWS.F', 'LION', 'TIE.AS', 'IHC', 'HMHC', 'PTSC', 'ORIENTBANK.NS', 'ORBK', 'QSC.F', 'ZENO', 'WDI.F', 'CRY', 'ASBE.L', 
#          'AIMT', 'RXN', 'INAP', 'QS5.F', 'ECHO', 'ATVI', 'RNET', 'HNP', 'TODAYS.NS', 'NBI.L', 'AMP.L', 'TTI.BE', 'QTS', 'SRYB', 'CCGN', 'PRLX', 'SHRIRAMCIT.NS', 'PANORAMUNI.NS', 'LUB', 'AFBG', 'ATEA', 'ATQT.L', 'RUBI', 'LEDIF', 'NEWM', 'SENZ', 'SHRE.L', 'PTNR', 'LOGM', 'VSBN', 'JASO', 'PAPERPROD.NS', '3IINFOTECH.NS', 'NXTM', 'IMSU', 'ROKR', 'RAVN', 'STFC', 'DFRG', 'UFS', 'GLOP', 'CMO', 'OPB', 'WMEG', 'BHARATIDIL.NS', 'TSGL', 'MOST', 'AOR.L', 'CHL', 'MCKS.L', 'PKI', 'IBPO.L', 'SUBEX.NS', 'UTC1.BE', 'STERLINBIO.NS', 'FISV', 'HWCC', 'ZOOM', 'MUR.L', 'CTL', 'FBHS', 'ALAN', 'ONCE', 'AAQ.MU', 'NCR', 'GARDENSILK.NS', 'DPA.AS', 'COFI', 'HHC', 'PAL.L', 'MYL', 'ETFC', 'SICAL.NS', 'SYMC', 'GDL.NS', 'RFP', 'HHWW', 'UNITEDBNK.NS', 'HYNS.L', 'O1BC.BE', 'BMTC', 'PHTM.L', 'P1Z.BE', 'EXCELCROP.NS', 'TLI.BE', 'OMAG', 'NKTN.L', 'GKS.BE', 'SURANAIND.NS', 'NAO', 'MYDX', 'CHA', 'NANO', 'MEGH.NS', 'ROLL', 'STRTECH.NS', 'GPLA', 'BBA.L', 'BBL', 'LNGB', 'NUM.L', 'MAXE', 'CEA', 'TRKK', 'BEL', 'HIL', 'OSR.BE', 'ESL', 'SRMC', 'CNTF', 'FOX.L', 'BARTRONICS.NS', 'IORG', 'ANO.MU', 'BORN', 'KSK.L', 'JCOM', 'BRBW', 'KNIA.BE', 'PV3.BE', 'RECN', 'LXB.L', 'SAF.L', 'MGLN', 'STON', 'HCHC', 'FBNK', 'EMCI', 'DEST', 'NMC.L', 'SMPL.NS', 'OPNT', 'OFC', 'HP3.BE', 'MU4.BE', 'GLBL', 'MSLP', 'SPAR', 'DDDD.L', 'LYNS', 'DL', 'AMAG', 'BBT', 'TSU', 'BSPE', 'GRDH', 'ORBC', 'ECOL', 'IDH.L', 'KCOM.L', 'PRGX', 'DIGS.L', 'MNTA', 'GTT', 'LAKSHVILAS.NS', 'FAM1.MU', 'NLMK.L', 'MMC.L', 'ABB', 'POLY.L', 'FDI.L', 'AMO.L', 'ADL.MU', 'CDK', 'DCD.L', 'CTDH', 'UBNT', 'VTL', 'VIJSHAN.NS', 'TI', 'WEG1.BE', 'VRTB', 'WHHT', 'WDR', 'IFP.L', 'PS4.F', 'SMTG.L', 'JCAP', 'DSW', 'PROZONINTU.NS', 'SYX', 'CHU', 'MON', 'HEXAWARE.NS', 'TLA.L', 'BTHE', 'MBDE', 'VIVO', 'AMCN', 'CTH.L', 'CIN.L', 'ADI1.BE', 'LB', 'CNAB', 'QUMU', 'NATI', 'RDI.L', 'PLP.L', 'IBAL', 'CSII', 'DLG.BE', 'LNDC', 'CIIX', 'EIH.L', 'TERP', 'ALBK.NS', 'LLEN', 'INVT', 'KHAITANELE.NS', 'NJMC', 'CLCN', 'CONE', 'ROHITFERRO.NS', 'CSHB', 'WNDM', 'ZAR.BE', 'SCVM', 'EKT.L', 'SNH', 'CINE.L', 'ELAND.NS', 'CSRH', 'CTB', 'ZMTP', 'LITL.NS', 'GFK.BE', 'CYNK', 'SALORAINTL.NS', 'HARI', 'GOAL.L', 'COWN', 'ULE.L', 'CSTU', 'ZAYO', 'VEC.L', 'PGRD', 'CADILAHC.NS', 'RRD', 
#     'PVCS.L','VRX', 'ZPIN', 'PSTB', 'AXPW', 'DOCD.AS', 'DPL.NS', 'AFL.NS', 'QFOR', 'CGI', 'GARWALLROP.NS', 'MYCC', 'BRCD', 'BKFS', 'RHSC', 'RSO', 'CEMP', 'DPS', 'SONS', 'AGU', 'EDRG', '0QE8.L', 'LDR', 'PWRV', 'ABY', 'RAIREKMOH.NS', 'EMQ.F', 'COH', 'XTRN', 'HNET', 'DLTZ', 'GGP', 'KKB.L', 'HCLP', 'UTMR', 'LVLT', 'NQ', 'TJI.L', 'PML.L', 'CYLU', 'ACAR', 'EMON', 'DIMN', 'FPO', 'BLQN', 'PWEB', 'CBF', 'VSUL', 'TNI.L', 'MNAI', 'UTTAMVALUE.NS', 'FBDU.L', 'WR', 'SNBN', 'USPR', 'ABIRLANUVO.NS', 'SNBC', 'GIMO', 'KSBPUMPS.NS', 'GBSN', 'ROII', 'WSTC', 'MJPI', 'ANANDAMRUB.NS', 'DGI', 'IVO.L', 'TWFH', 'KITE', 'MSG.L', 'ACL.L', 'ASAE', 'STI.L', 'GEN.AS', 'WMLP', 'SPRP.L', 'RDEL.NS', 'DDRT', 'CDI', 'RAS', 'PN', 'PITTILAM.NS', 'OMGB', 'STVI', 'SIA.AS', 'RTBC', 'DALP', 'SGBK', 'IXYS', 'VRHD', 'ISGI', 'NUIN', 'NVA.L', 'TCKF', 'ICPTF', 'DDR', 'CHUM', 'OTC.L', 'IMTK.L', 'MIO.L', 'AEI.F', 'EGS.L', 'GBSX', 'SGZH', 'Q', 'TCAP', 'UBI.L', 'PANG', 'WAC', 'OTMT.L', 'FCH', 'ENUM', 'MTGB', 'XNY', 'ACXM', 'QP.L', 'TICC', 'MCAR', 'WBMD', 'LUK', 'TISN.AS', 'DFT', 'ABCO', 'ESL.NS', 'DEPO', 'SCSS', 'SFO.F', 'PKG.L', 'GREW', 'YGE', 'ENTU.L', 'CCGI', 'SPHEREGSL.NS', 'CETH', 'NMRX', 'KORS', 'PAYM', 'ANTB', 'ADAT', 'GDFI', 'VNTV', 'DOMK', 'CCE', 'RT', 'HLS', 'MZEI', 'CTOT', 'MYEC', 'CZYB', 'AJAC', 'AKDS', 'AMRI', 'EDMC', 'CMTB', 'CABN', 'NYLD', 'SGP.L', 'AGII', 'QTM', 'VIS.L', 'RBCF', 'PCLN', 'ENVV', 'ALAD', 'SHIVTEX.NS', 'TRIC.L', 'BHUSANSTL.NS', 'DTC.L', 'PDUMJEPULP.NS', 'AMBOY', 'ILNS', 'PKY', 'CBG', 'PUB.L', 'SULA.L', 'NNS.F', 'QVCA', 'PLA.L', 'RUS.L', 'IDFCBANK.NS', 'WOR.L', 'OAKS', 'ALFE', 'CNMI.L', 'RIGI', 'HPCQ', 'UHLN', 'BSFT', 'AGP.L', 'MGN.BE', 'PABL', 'PMC', 'GSEN', 'KENV.L', 'GFK.F', 'TEVE', 'IEBS', 'DISHMAN.NS', 'POT', 'P1Z.F', 'OREX', 'CSAX', 'ICPW', 'MLIN.L', 'EOMN', 'GOLDINFRA.NS', 'BOBE', 'BIRLACOT.NS', 'SPHR.L', 'QSII', 'MANY', 'TRPO', 'MDFI', 'PRGB', 'IDGS', 'DLPM', 'MASA.L', 'CDIF', 'OMVS', 'ESSX', 'ENZY', 'MNBT', 'GRMS', 'AMTL.NS', 'SNC', 'ISYG', 'HISP', 'GEIG', 'RLIA', 'PKGM', 'ONL.L', 'GOV', 'GPLH', 'LVNTA', 'GLPW', 'NEWS', 'CROS.L', 'IFGLREFRAC.NS', 'HCN', 'HSHS', 'NTL', 'SGMZ', 'LEG.L', 'NEFF', 'AHP', 'NWIG.L', 'CNCK', 'CUMD', 'PHOENIXLL.NS', 'BWLD', 'PAA.L', 'IMG.L', 'KYO', 'NULM', 'GFA', 'IPOW', 'DGB.L', 'NIPT.L', 'KWE.L', 'MU4.F', 'SCLN', 'BFC.BE', 'MTU', 'FCR.L', 'HBHC', 'BOMK', 'UL.AS', 'OPLI', 'HYH', 'VSAR', 'HLTK', 'LMOS', 'ZZZ.L', 'SEINV.NS', 'BLUR.L', 'SHGT', 'VCO', 'PTSX', 'CECB', 'ATOC', 'GEZC', 'BCR', 'PRXL', 'AERO.L', 'EMAMIINFRA.NS', 'APGA', 'REON', 'CLST.L', 'PRISMCEM.NS', 'SVON', 'CAB', 'WYN', 'HRG', 'HEZ.F', 'MONI.L', 'SHOR', 'BDR.NS', 'WAFM.L', 'IEH.L', 'NWY', 'ROGI', 'LYCOS.NS', 'COYN', 'FMSA', 'SFCL.NS', 'OKSB', 'SERV.L', 'CZA.L', 'SWFT', 'LBSV', 'KBC.F', 'APPO', 'SSNI', 'GULD', 'FAC', 'AIRW', 'GREENFIRE.NS', 'CDII', 'TRYF', 'FOFN', 'HOMR', 'PLLX', 'HZNB', 'PHMD', 'EXAD', 'DPDM', 'NYO.L']

All_Tickers = [ticker for ticker in All_Tickers if ticker not in Removed]

print(All_Tickers)
len(All_Tickers)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CPAY', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 
# ...

# %%
prices_data = yf.download(All_Tickers,start='2005-01-01')['Adj Close']
# Out:
# [*********************100%%**********************]  504 of 504 completed
# 2 Failed downloads:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2005-01-01 -> 2024-06-05)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
# prices_data=pd.read_csv('BackupPrice.csv')
prices=prices_data.copy()
# prices=prices.set_index('Date')
prices
# Out:
#                      A    AAL        AAPL        ABBV        ABNB         ABT  \
# Date
# 2005-01-03   14.464984    NaN    0.955513         NaN         NaN   14.226124
# 2005-01-04   14.083369    NaN    0.965326         NaN         NaN   14.082851
# 2005-01-05   14.077314    NaN    0.973780         NaN         NaN   13.921297
# 2005-01-06   13.768388    NaN    0.974536         NaN         NaN   14.235261
# 2005-01-07   13.756269    NaN    1.045492         NaN         NaN   14.479123
# ...                ...    ...         ...         ...         ...         ...
# 2024-05-30  131.419998  11.44  191.289993  156.309998  145.520004  101.739998
# 2024-05-31  130.410004  11.50  192.250000  161.240005  144.929993  102.190002
# 2024-06-03  131.399994  11.53  194.029999  160.190002  146.250000  102.870003
# 2024-06-04  130.850006  11.50  194.350006  162.139999  147.080002  103.430000
# 2024-06-05  133.559998  11.62  195.869995  165.440002  145.779999  103.230003
#
# ...

# %%
import pandas as pd
from pandas.tseries.holiday import USFederalHolidayCalendar
from datetime import datetime, timedelta

def get_us_working_days(start_year, end_year):
    all_working_days = []

    for year in range(start_year, end_year + 1):
        # Create a US Federal Holiday calendar
        cal = USFederalHolidayCalendar()

        # Get all holidays for the specified year
        holidays = cal.holidays(datetime(year, 1, 1), datetime(year, 12, 31))

        # Generate a range of dates for the specified year
        start_date = datetime(year, 1, 1)
        end_date = datetime(year, 12, 31)
        date_range = pd.date_range(start_date, end_date)

        # Filter out weekends (Saturday and Sunday) and holidays
        working_days = [date for date in date_range if date.weekday() < 5 and date not in holidays]

        all_working_days.extend(working_days)

    return all_working_days

# Example: Get all US working days between 2005 and 2023
start_year = 2005
end_year = 2024
us_working_days_2005_to_2023 = get_us_working_days(start_year, end_year)
print(us_working_days_2005_to_2023)
dates_to_remove = ['2015-04-03', '2016-03-25', '2017-04-14', '2018-03-30', '2021-04-02', '2022-04-15', '2023-04-07']

# Using a list comprehension
us_working_days_2005_to_2023 = [date for date in us_working_days_2005_to_2023 if date not in dates_to_remove]

# Alternatively, using filter and lambda
us_working_days_2005_to_2023 = list(filter(lambda date: date not in dates_to_remove, us_working_days_2005_to_2023))
# Out:
# [Timestamp('2005-01-03 00:00:00'), Timestamp('2005-01-04 00:00:00'), Timestamp('2005-01-05 00:00:00'), Timestamp('2005-01-06 00:00:00'), Timestamp('2005-01-07 00:00:00'), Timestamp('2005-01-10 00:00:00'), Timestamp('2005-01-11 00:00:00'), Timestamp('2005-01-12 00:00:00'), Timestamp('2005-01-13 00:00:00'), Timestamp('2005-01-14 00:00:00'), Timestamp('2005-01-18 00:00:00'), Timestamp('2005-01-19 00:00:00'), Timestamp('2005-01-20 00:00:00'), Timestamp('2005-01-21 00:00:00'), Timestamp('2005-01-24 00:00:00'), Timestamp('2005-01-25 00:00:00'), Timestamp('2005-01-26 00:00:00'), Timestamp('2005-01-27 00:00:00'), Timestamp('2005-01-28 00:00:00'), Timestamp('2005-01-31 00:00:00'), Timestamp('2005-02-01 00:00:00'), Timestamp('2005-02-02 00:00:00'), Timestamp('2005-02-03 00:00:00'), Timestamp('2005-02-04 00:00:00'), Timestamp('2005-02-07 00:00:00'), Timestamp('2005-02-08 00:00:00'), Timestamp('2005-02-09 00:00:00'), Timestamp('2005-02-10 00:00:00'), Timestamp('2005-02-11 00:00:00'), Timestamp('
# ...

# %%
prices=prices.drop(columns=['DECK', 'HPQ', 'IP'])

# %%
start_date = datetime.today() - pd.DateOffset(months=1)

# Extract the data for the last year
prices_train = prices.loc[start_date:]
df = prices_train.copy()
# df = df[df.index.weekday < 5]
df = df[df.index.isin(us_working_days_2005_to_2023)]
df = df[df.index != pd.Timestamp('2018-12-05')]
df = df[df.index != pd.Timestamp('2015-01-01')]
df = df[df.index != pd.Timestamp('2019-04-19')]
df = df[df.index != pd.Timestamp('2019-05-27')]
df = df[df.index != pd.Timestamp('2020-04-10')]
num_rows_after_dropna = df.dropna(axis=1).shape[1]
if num_rows_after_dropna<10:
    print('Done this')
    df=df.interpolate(method='linear')
    # df=df.backfill()
    df=df.dropna(axis=1)
else:
    print('Done that')
    df=df.dropna(axis=1)
print(str(df.index[-1])+f"and "+str(df.index[0]))
print(len(df.columns))
# Calculate expected returns and sample covariance
mu = expected_returns.mean_historical_return(df)
S = risk_models.risk_matrix(df, method='ledoit_wolf')
ef = EfficientFrontier(mu, S,weight_bounds=(0, 0.4))
# raw_weights = ef.efficient_return(target_return=mu.max()-47)
i = 0
while True:
    try:
        raw_weights = ef.efficient_return(target_return=mu.max()-i)
        print(f"Selected i is {i}")
        break
    except Exception as e:
        # print(f"Error for i={i}: {e}")
        i += 0.01

print(f"First successful i: {i}")
print(f"Raw weights: {raw_weights}")
# raw_weights=ef.max_sharpe()
cleaned_weights = ef.clean_weights()
ef.portfolio_performance(verbose=True)
filtered_data = [(name, value) for name, value in cleaned_weights.items() if value > 0.1]
print(filtered_data)
# Out:
# Done that
# 2024-06-05 00:00:00and 2024-05-06 00:00:00
# 499
# c:\Users\adnan\AppData\Local\Programs\Python\Python39\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:336: FutureWarning:
#     Your problem is being solved with the ECOS solver by default. Starting in
#     CVXPY 1.5.0, Clarabel will be used as the default solver instead. To continue
#     using ECOS, specify the ECOS solver explicitly using the ``solver=cp.ECOS``
#     argument to the ``problem.solve`` method.
#
#   warnings.warn(ECOS_DEPRECATION_MSG, FutureWarning)
# Selected i is 5.5299999999999265
# First successful i: 5.5299999999999265
# ...

# %%
prices2=prices.copy()
prices2 = prices2[prices2.index.isin(us_working_days_2005_to_2023)]
# prices2 = prices2[prices2.index.weekday < 5]
prices2=prices2.interpolate(method='linear')
prices2=prices2.reset_index()
melted_df = pd.melt(prices2, id_vars=['Date'], var_name='Stock', value_name='Value')
melted_df
# Out:
#               Date  Stock        Value
# 0       2005-01-03      A    14.464979
# 1       2005-01-04      A    14.083371
# 2       2005-01-05      A    14.077308
# 3       2005-01-06      A    13.768384
# 4       2005-01-07      A    13.756271
# ...            ...    ...          ...
# 2441875 2024-05-24  ^GSPC  5304.720215
# 2441876 2024-05-28  ^GSPC  5306.040039
# 2441877 2024-05-29  ^GSPC  5266.950195
# 2441878 2024-05-30  ^GSPC  5235.479980
# 2441879 2024-05-31  ^GSPC  5277.509766
#
# [2441880 rows x 3 columns]

# %%
invested_amount=1100

Investment=pd.DataFrame(filtered_data)
Investment=Investment.rename(columns={0:'Stock',1:'Share'})
Investment['Invested amount']=invested_amount*Investment['Share']

# %%
Latest_Prices=melted_df[melted_df['Date']=='2024-06-04']
Latest_Prices
# Out:
# Empty DataFrame
# Columns: [Date, Stock, Value]
# Index: []

# %%
Full_Data=pd.merge(Investment,Latest_Prices,on='Stock',how='left')
Full_Data['Number of shares purchased']=Full_Data['Invested amount']/Full_Data['Value']
Full_Data
# Out:
#   Stock    Share  Invested amount Date  Value  Number of shares purchased
# 0  DECK  0.40000          440.000  NaT    NaN                         NaN
# 1   HPQ  0.38073          418.803  NaT    NaN                         NaN
# 2    IP  0.16068          176.748  NaT    NaN                         NaN

# %%
# Out:
# 0.81084
